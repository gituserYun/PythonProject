# %% [markdown]
# 리스트와 함께 사용

# %%
fruit = ['사과', '배', '딸기', '포도']
print(fruit)
fruit.append('귤')
print(fruit)
if '딸기' in fruit:
    print("딸기 존재")
# Out:
# ['사과', '배', '딸기', '포도']
# ['사과', '배', '딸기', '포도', '귤']
# 딸기 존재

# %%
# Code05-10.py
import random

numbers=[]
for num in range(0,10):
    numbers.append(random.randrange(0,10))
    
print("생성된 리스트", numbers)

for num in range(0,10):
    if num not in numbers:
        print("숫자 %d는 리스트에 없다."%(num))
# Out:
# 생성된 리스트 [0, 9, 3, 7, 0, 0, 7, 5, 5, 4]
# 숫자 1는 리스트에 없다.
# 숫자 2는 리스트에 없다.
# 숫자 6는 리스트에 없다.
# 숫자 8는 리스트에 없다.

# %%
# 기능이 두 가지인 종합 계산기 프로그램
# Code05-11.py
## 변수 선언 부분 ##
select, answer, numStr, num1, num2 = 0, 0, "", 0, 0

## 메인 코드 부분 ##
select = int(input("1. 입력한 수식 계산 2. 두 수 사이의 합계: "))

if select == 1:
    numStr = input(" *** 수식을 입력하세요: ")
    answer = eval(numStr)
    print("%s의 결과는 %5.1f입니다."%(numStr, answer))
elif select == 2:
    num1 = int(input(" *** 첫 번째 숫자를 입력하세요: "))
    num2 = int(input(" *** 두 번째 숫자를 입력하세요: "))
    for i in range(num1, num2+1):
        answer = answer + i
        print("%d+...+%d는 %d입니다."%(num1, i, answer))
else:
    print("1 또는 2만 입력해야 합니다.")
# Out:
# 1+...+1는 1입니다.
# 1+...+2는 3입니다.
# 1+...+3는 6입니다.
# 1+...+4는 10입니다.
# 1+...+5는 15입니다.
# 1+...+6는 21입니다.
# 1+...+7는 28입니다.
# 1+...+8는 36입니다.
# 1+...+9는 45입니다.
# 1+...+10는 55입니다.
# 1+...+11는 66입니다.
# 1+...+12는 78입니다.
# 1+...+13는 91입니다.
# 1+...+14는 105입니다.
# 1+...+15는 120입니다.
# 1+...+16는 136입니다.
# 1+...+17는 153입니다.
# 1+...+18는 171입니다.
# 1+...+19는 190입니다.
# 1+...+20는 210입니다.
# 1+...+21는 231입니다.
# 1+...+22는 253입니다.
# 1+...+23는 276입니다.
# 1+...+24는 300입니다.
# 1+...+25는 325입니다.
# 1+...+26는 351입니다.
# 1+...+27는 378입니다.
# 1+...+28는 406입니다.
# 1+...+29는 435입니다.
# 1+...+30는 465입니다.
# 1+...+31는 496입니다.
# 1+...+32는 528입니다.
# 1+...+33는 561입니다.
# 1+...+34는 595입니다.
# 1+...+35는 630입니다.
# 1+...+36는 666입니다.
# 1+...+37는 703입니다.
# 1+...+38는 741입니다.
# 1+...+39는 780입니다.
# 1+...+40는 820입니다.
# 1+...+41는 861입니다.
# 1+...+42는 903입니다.
# 1+...+43는 946입니다.
# 1+...+44는 990입니다.
# 1+...+45는 1035입니다.
# 1+...+46는 1081입니다.
# 1+...+47는 1128입니다.
# 1+...+48는 1176입니다.
# 1+...+49는 1225입니다.
# 1+...+50는 1275입니다.
# ...

# %%
# 응용
## 변수 선언 부분 ##
select, answer, numStr, num1, num2 = 0, 0, "", 0, 0

## 메인 코드 부분 ##
select = int(input("1. 입력한 수식 계산 2. 두 수 사이의 합계: "))

if select == 1:
    numStr = input(" *** 수식을 입력하세요: ")
    answer = eval(numStr)
    print("%s의 결과는 %5.1f입니다."%(numStr, answer))
elif select == 2:
    num1 = int(input(" *** 첫 번째 숫자를 입력하세요: "))
    num2 = int(input(" *** 두 번째 숫자를 입력하세요: "))
    num3 = int(input(" *** 더할 숫자를 입력하세요: "))
    for i in range(num1, num2+1, num3):
        answer = answer + i
    print("%d+%d+...+%d는 %d입니댜."%(num1, num1 + num3, num2, answer))
else:
    print("1 또는 2만 입력해야 합니다.")
# Out:
# 1+4+...+100는 1717입니댜.

# %%
# 숫자를 하나 입력받고, 그 숫자가 소수인지를 체크하는 프로그램
num = int(input("숫자를 입력하세요: "))
if num < 2:
    print("%d는 소수가 아닙니다." % num)
else:
    isPrime = True
    for i in range(2, num):
        if num % i == 0:
            isPrime = False
            break
    
    if isPrime:
        print("%d는 소수입니다." % num)
    else:
        print("%d는 소수가 아닙니다." % num)
# 소수: 2,3,5,7,9,11,13,...
# Out:
# 7는 소수입니다.
